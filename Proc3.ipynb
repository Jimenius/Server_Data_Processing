# %%
from pyspark.sql import SparkSession
import re
from operator import add
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext

# %%
rdd = sc.textFile('epa-http.txt')
url_pat = re.compile('(([0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\.){3}([0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]).*')
rdd = rdd.filter(lambda x: url_pat.match(x) and x[-1] != '-').map(lambda x: x.split(' '))
rdd = rdd.map(lambda x: [x[0], x[1], x[-1]])

# %%
def time_period(x):
    time = x[1][1: -1]
    time_list = time.split(':')
    sec = ((int(time_list[0]) - 29) * 86400 + int(time_list[1]) * 3600 + \
           int(time_list[2]) * 60 + int(time_list[3]) - (23 * 3600 + 53 * 60 + 25))
    return [(x[0], sec / 3600), int(x[2])]

# %%
time_parser = rdd.map(time_period)

# %%
count = time_parser.reduceByKey(add)
res = count.collect()

# %%
for k, v in count.collect():
    print v, 'bytes are served to', k[0], 'in the hour period', k[1] + 1
# Out:
# 65809 bytes are served to 138.13.122.153 in the hour period 15
# 1824 bytes are served to 141.209.3.136 in the hour period 22
# 81406 bytes are served to 146.142.48.156 in the hour period 15
# 15275 bytes are served to 199.170.79.49 in the hour period 14
# 195429 bytes are served to 199.8.210.73 in the hour period 21
# 2624 bytes are served to 130.206.105.165 in the hour period 12
# 23026 bytes are served to 130.207.94.51 in the hour period 16
# 767538 bytes are served to 131.167.25.3 in the hour period 10
# 12348 bytes are served to 147.154.93.104 in the hour period 16
# 141003 bytes are served to 204.188.47.212 in the hour period 24
# 24376 bytes are served to 204.5.81.30 in the hour period 17
# 157189 bytes are served to 131.126.30.164 in the hour period 17
# 104754 bytes are served to 159.238.20.194 in the hour period 19
# 68101 bytes are served to 155.79.153.164 in the hour period 14
# 11747 bytes are served to 205.138.140.2 in the hour period 12
# 14449 bytes are served to 137.159.177.111 in the hour period 14
# 28263 bytes are served to 139.121.79.159 in the hour period 11
# 47492 bytes are served to 38.12.1.154 in the hour period 11
# 212306 bytes are served to 128.163.17.212 in the hour period 15
# 56431 bytes are served to 192.231.202.61 in the hour period 14
# 24842 bytes are served to 204.62.245.32 in the hour period 6
# 52225 bytes are served to 204.254.252.116 in the hour period 20
# 11747 bytes are served to 152.123.183.212 in the hour period 9
# 115492 bytes are served to 155.84.91.40 in the hour period 10
# 4888 bytes are served to 157.145.93.27 in the hour period 16
# 14507 bytes are served to 134.53.24.216 in the hour period 13
# 41943 bytes are served to 204.165.200.88 in the hour period 23
# 14963 bytes are served to 192.231.222.131 in the hour period 13
# 28226 bytes are served to 138.87.174.185 in the hour period 20
# 11747 bytes are served to 192.154.33.201 in the hour period 12
# 2624 bytes are served to 131.120.147.33 in the hour period 15
# 112011 bytes are served to 199.77.66.14 in the hour period 21
# 32988 bytes are served to 128.255.51.142 in the hour period 15
# 5388 bytes are served to 128.180.28.3 in the hour period 16
# 876514 bytes are served to 161.122.12.78 in the hour period 3
# 25431 bytes are served to 131.95.119.99 in the hour period 22
# 106260 bytes are served to 132.248.53.29 in the hour period 15
# 26812 bytes are served to 159.105.44.21 in the hour period 10
# 34095 bytes are served to 144.39.248.101 in the hour period 14
# 46717 bytes are served to 128.165.180.61 in the hour period 16
# 11747 bytes are served to 138.26.154.176 in the hour period 11
# 132997 bytes are served to 131.52.16.102 in the hour period 12
# 71519 bytes are served to 192.217.93.159 in the hour period 10
# 15019 bytes are served to 192.246.249.29 in the hour period 13
# 2624 bytes are served to 204.250.21.9 in the hour period 22
# 74329 bytes are served to 163.234.112.156 in the hour period 11
# 69511 bytes are served to 134.67.41.20 in the hour period 17
# 672345 bytes are served to 198.106.169.52 in the hour period 17
# 35500 bytes are served to 192.48.125.149 in the hour period 9
# 14450 bytes are served to 198.109.184.42 in the hour period 12
# 11746 bytes are served to 192.43.248.62 in the hour period 17
# 11746 bytes are served to 129.93.222.79 in the hour period 14
# 8906 bytes are served to 192.58.206.21 in the hour period 10
# 38248 bytes are served to 198.137.145.112 in the hour period 17
# 971 bytes are served to 146.137.152.20 in the hour period 13
# 106681 bytes are served to 192.58.206.21 in the hour period 20
# 44317 bytes are served to 133.62.128.131 in the hour period 22
# 19910 bytes are served to 129.187.250.1 in the hour period 10
# 27205 bytes are served to 130.241.163.40 in the hour period 16
# 11808 bytes are served to 131.247.150.153 in the hour period 17
# 35178 bytes are served to 164.158.3.218 in the hour period 13
# 306645 bytes are served to 200.246.227.108 in the hour period 12
# 16348 bytes are served to 148.149.107.147 in the hour period 15
# 12743 bytes are served to 157.145.93.27 in the hour period 18
# 25369 bytes are served to 160.136.18.53 in the hour period 14
# 7512 bytes are served to 150.216.67.4 in the hour period 15
# 4888 bytes are served to 198.111.36.11 in the hour period 14
# 20475 bytes are served to 155.77.120.28 in the hour period 12
# 14963 bytes are served to 161.119.52.62 in the hour period 14
# 2624 bytes are served to 161.225.48.3 in the hour period 17
# 230 bytes are served to 146.83.128.83 in the hour period 10
# 27129 bytes are served to 165.152.208.237 in the hour period 12
# 98546 bytes are served to 129.81.186.112 in the hour period 15
# 5000 bytes are served to 204.252.77.88 in the hour period 15
# 50414 bytes are served to 158.185.86.130 in the hour period 13
# 24063 bytes are served to 198.80.60.13 in the hour period 17
# 47666 bytes are served to 199.222.162.25 in the hour period 16
# 39734 bytes are served to 192.137.112.52 in the hour period 19
# 223233 bytes are served to 139.121.98.45 in the hour period 13
# 58579 bytes are served to 139.104.10.167 in the hour period 16
# 126120 bytes are served to 156.63.91.107 in the hour period 15
# 51880 bytes are served to 199.1.106.1 in the hour period 22
# 3273 bytes are served to 148.224.17.200 in the hour period 12
# 3517 bytes are served to 159.142.162.78 in the hour period 11
# 179570 bytes are served to 163.234.116.45 in the hour period 13
# 1897 bytes are served to 138.87.174.195 in the hour period 17
# 54949 bytes are served to 134.186.194.4 in the hour period 15
# 39957 bytes are served to 136.205.176.110 in the hour period 11
# 18574 bytes are served to 203.1.203.100 in the hour period 24
# 93362 bytes are served to 129.252.188.166 in the hour period 15
# 53638 bytes are served to 163.206.111.16 in the hour period 17
# 507904 bytes are served to 156.41.19.11 in the hour period 16
# 41326 bytes are served to 205.133.212.1 in the hour period 20
# 2730 bytes are served to 199.249.179.23 in the hour period 17
# 24476 bytes are served to 144.92.46.13 in the hour period 15
# 17607 bytes are served to 130.38.73.80 in the hour period 14
# 11746 bytes are served to 161.156.150.116 in the hour period 16
# 18356 bytes are served to 139.102.65.47 in the hour period 20
# 0 bytes are served to 149.4.13.48 in the hour period 12
# 52225 bytes are served to 137.243.44.118 in the hour period 19
# 4889 bytes are served to 205.197.136.141 in the hour period 8
# 5226 bytes are served to 150.192.45.67 in the hour period 12
# 93175 bytes are served to 128.227.144.18 in the hour period 13
# 14465 bytes are served to 156.63.155.156 in the hour period 11
# 93491 bytes are served to 156.63.241.113 in the hour period 16
# 338376 bytes are served to 129.237.24.71 in the hour period 14
# 14450 bytes are served to 164.156.42.105 in the hour period 12
# 116036 bytes are served to 131.167.99.59 in the hour period 15
# 137500 bytes are served to 148.224.17.21 in the hour period 20
# 11747 bytes are served to 168.154.26.10 in the hour period 6
# 11747 bytes are served to 192.239.68.110 in the hour period 7
# 11515 bytes are served to 146.138.145.126 in the hour period 14
# 80786 bytes are served to 192.246.73.101 in the hour period 11
# 192782 bytes are served to 141.243.1.172 in the hour period 2
# 54461 bytes are served to 142.140.32.21 in the hour period 16
# 11746 bytes are served to 128.158.53.34 in the hour period 16
# 32173 bytes are served to 149.79.176.84 in the hour period 12
# 2665 bytes are served to 147.46.54.150 in the hour period 9
# 39435 bytes are served to 137.161.153.224 in the hour period 16
# 0 bytes are served to 157.145.93.27 in the hour period 20
# 15340 bytes are served to 155.206.19.108 in the hour period 13
# 23999 bytes are served to 157.182.94.210 in the hour period 11
# 53603 bytes are served to 163.234.34.150 in the hour period 11
# 11762 bytes are served to 204.252.77.45 in the hour period 16
# 96707 bytes are served to 149.168.25.115 in the hour period 14
# 4888 bytes are served to 128.97.218.144 in the hour period 16
# 5897 bytes are served to 192.58.204.203 in the hour period 11
# 24866 bytes are served to 140.96.17.110 in the hour period 10
# 97879 bytes are served to 129.132.182.34 in the hour period 7
# 15820 bytes are served to 149.123.103.99 in the hour period 11
# 82636 bytes are served to 202.32.50.6 in the hour period 4
# 86125 bytes are served to 146.114.26.12 in the hour period 20
# 75563 bytes are served to 165.151.47.249 in the hour period 20
# 11746 bytes are served to 128.150.157.33 in the hour period 13
# 32658 bytes are served to 192.146.118.133 in the hour period 6
# 9185 bytes are served to 163.178.128.205 in the hour period 14
# 7188 bytes are served to 150.216.15.141 in the hour period 20
# 43686 bytes are served to 129.162.13.175 in the hour period 15
# 64304 bytes are served to 147.160.9.24 in the hour period 11
# 2329 bytes are served to 165.113.166.116 in the hour period 16
# 57523 bytes are served to 153.64.63.35 in the hour period 15
# 11516 bytes are served to 140.120.29.161 in the hour period 2
# 144396 bytes are served to 128.138.177.19 in the hour period 23
# 52321 bytes are served to 158.229.201.74 in the hour period 16
# 11747 bytes are served to 204.157.204.201 in the hour period 10
# 15663 bytes are served to 134.243.230.108 in the hour period 17
# 0 bytes are served to 134.67.39.48 in the hour period 14
# 19910 bytes are served to 128.227.109.32 in the hour period 12
# 7477 bytes are served to 134.186.196.20 in the hour period 12
# 4950 bytes are served to 205.217.0.115 in the hour period 20
# 70383 bytes are served to 198.104.228.83 in the hour period 15
# 12610 bytes are served to 193.145.151.115 in the hour period 13
# 104910 bytes are served to 129.243.129.234 in the hour period 16
# 11808 bytes are served to 134.67.195.123 in the hour period 17
# 5686 bytes are served to 203.1.203.111 in the hour period 2
# 4888 bytes are served to 131.126.30.164 in the hour period 15
# 11808 bytes are served to 198.215.148.176 in the hour period 19
# 4888 bytes are served to 199.11.62.136 in the hour period 13
# 12103 bytes are served to 134.243.205.184 in the hour period 9
# 5830 bytes are served to 129.193.186.72 in the hour period 16
# 4889 bytes are served to 128.104.66.114 in the hour period 13
# 34462 bytes are served to 198.69.241.75 in the hour period 2
# 1052103 bytes are served to 128.159.128.27 in the hour period 11
# 262144 bytes are served to 128.227.152.54 in the hour period 10
# 7758 bytes are served to 192.228.164.77 in the hour period 6
# 111363 bytes are served to 204.97.68.29 in the hour period 10
# 220449 bytes are served to 198.88.26.109 in the hour period 12
# 24576 bytes are served to 146.138.34.168 in the hour period 16
# 13925 bytes are served to 132.236.38.122 in the hour period 18
# 4889 bytes are served to 199.111.26.62 in the hour period 10
# 13205 bytes are served to 202.244.226.77 in the hour period 7
# 15019 bytes are served to 143.139.25.15 in the hour period 16
# 39721 bytes are served to 134.53.98.16 in the hour period 15
# 11515 bytes are served to 155.77.120.18 in the hour period 15
# 118278 bytes are served to 205.208.30.114 in the hour period 13
# 1088549 bytes are served to 204.7.162.158 in the hour period 14
# 53504 bytes are served to 147.46.54.150 in the hour period 7
# 42748 bytes are served to 143.188.9.163 in the hour period 24
# 44356 bytes are served to 150.148.56.13 in the hour period 10
# 173168 bytes are served to 131.92.168.211 in the hour period 12
# 12588 bytes are served to 131.170.154.29 in the hour period 1
# 24558 bytes are served to 156.63.59.137 in the hour period 14
# 11747 bytes are served to 128.23.160.101 in the hour period 10
# 68345 bytes are served to 167.193.49.75 in the hour period 12
# 12195 bytes are served to 156.98.203.5 in the hour period 14
# 56846 bytes are served to 204.171.110.3 in the hour period 12
# 100174 bytes are served to 204.91.136.27 in the hour period 19
# 11747 bytes are served to 129.93.236.89 in the hour period 12
# 10556 bytes are served to 134.67.162.118 in the hour period 11
# 103178 bytes are served to 156.98.205.46 in the hour period 16
# 4950 bytes are served to 165.151.26.205 in the hour period 17
# 11747 bytes are served to 192.107.65.93 in the hour period 11
# 7004 bytes are served to 204.185.47.2 in the hour period 16
# 31525 bytes are served to 163.234.156.52 in the hour period 13
# 20464 bytes are served to 156.98.168.200 in the hour period 13
# 10542 bytes are served to 204.62.245.32 in the hour period 2
# 4889 bytes are served to 192.246.181.70 in the hour period 12
# 28257 bytes are served to 149.168.25.195 in the hour period 14
# 11747 bytes are served to 141.243.1.188 in the hour period 7
# 69622 bytes are served to 132.74.12.10 in the hour period 4
# 25710 bytes are served to 137.35.140.68 in the hour period 16
# 10901 bytes are served to 204.4.34.49 in the hour period 16
# 2520 bytes are served to 138.87.174.181 in the hour period 14
# 246078 bytes are served to 198.109.136.238 in the hour period 13
# 27832 bytes are served to 155.33.62.76 in the hour period 13
# 87450 bytes are served to 138.87.174.181 in the hour period 20
# 222764 bytes are served to 202.39.249.142 in the hour period 21
# 168250 bytes are served to 131.167.99.88 in the hour period 15
# 35339 bytes are served to 131.181.38.71 in the hour period 4
# 39758 bytes are served to 194.20.235.12 in the hour period 7
# 72125 bytes are served to 146.114.41.1 in the hour period 16
# 19396 bytes are served to 194.151.3.11 in the hour period 11
# 5250 bytes are served to 199.4.102.43 in the hour period 16
# 1122 bytes are served to 199.249.179.23 in the hour period 21
# 64100 bytes are served to 157.92.49.53 in the hour period 18
# 48299 bytes are served to 146.184.114.116 in the hour period 14
# 59437 bytes are served to 134.67.162.123 in the hour period 9
# 16109 bytes are served to 137.227.51.15 in the hour period 14
# 5830 bytes are served to 131.126.30.164 in the hour period 13
# 31059 bytes are served to 170.142.111.131 in the hour period 9
# 9134 bytes are served to 148.149.107.11 in the hour period 14
# 24183 bytes are served to 204.62.245.32 in the hour period 14
# 29236 bytes are served to 128.97.218.144 in the hour period 18
# 47635 bytes are served to 128.138.177.44 in the hour period 17
# 36851 bytes are served to 198.109.24.111 in the hour period 14
# 79272 bytes are served to 139.121.79.159 in the hour period 17
# 11747 bytes are served to 141.243.1.187 in the hour period 6
# 78317 bytes are served to 198.102.1.121 in the hour period 10
# 147250 bytes are served to 164.159.7.12 in the hour period 19
# 69641 bytes are served to 134.67.57.27 in the hour period 17
# 97063 bytes are served to 134.20.176.82 in the hour period 16
# 23877 bytes are served to 198.216.2.221 in the hour period 10
# 3073 bytes are served to 131.230.197.21 in the hour period 13
# 21821 bytes are served to 141.192.85.41 in the hour period 4
# 5686 bytes are served to 203.1.203.104 in the hour period 2
# 4950 bytes are served to 146.114.41.1 in the hour period 18
# 40644 bytes are served to 155.84.91.42 in the hour period 10
# 12587 bytes are served to 148.224.17.22 in the hour period 13
# 19032 bytes are served to 138.87.174.185 in the hour period 22
# 5282 bytes are served to 155.75.31.8 in the hour period 13
# 35749 bytes are served to 198.110.207.198 in the hour period 19
# 1054898 bytes are served to 146.138.34.168 in the hour period 14
# 8223 bytes are served to 148.224.17.200 in the hour period 20
# 37512 bytes are served to 131.110.56.66 in the hour period 10
# 53977 bytes are served to 134.243.205.239 in the hour period 16
# 9776 bytes are served to 204.171.110.3 in the hour period 16
# 30996 bytes are served to 146.138.145.203 in the hour period 12
# 103106 bytes are served to 141.233.130.130 in the hour period 16
# 33020 bytes are served to 161.122.12.78 in the hour period 1
# 45994 bytes are served to 204.255.215.49 in the hour period 20
# 39857 bytes are served to 139.94.97.6 in the hour period 14
# 5120 bytes are served to 206.26.139.15 in the hour period 11
# 120788 bytes are served to 129.15.32.106 in the hour period 12
# 4889 bytes are served to 199.11.48.9 in the hour period 12
# 11577 bytes are served to 149.136.2.181 in the hour period 20
# 53501 bytes are served to 142.142.64.13 in the hour period 10
# 11808 bytes are served to 129.93.229.104 in the hour period 21
# 46001 bytes are served to 128.252.99.104 in the hour period 14
# 80583 bytes are served to 165.110.45.53 in the hour period 19
# 42100 bytes are served to 204.194.170.100 in the hour period 15
# 11747 bytes are served to 141.243.1.184 in the hour period 5
# 11746 bytes are served to 146.138.12.103 in the hour period 13
# 15081 bytes are served to 192.74.216.248 in the hour period 21
# 5532 bytes are served to 146.63.206.253 in the hour period 19
# 3947 bytes are served to 128.148.245.158 in the hour period 17
# 11590 bytes are served to 134.126.28.83 in the hour period 14
# 32505 bytes are served to 134.7.60.128 in the hour period 11
# 23009 bytes are served to 129.162.205.5 in the hour period 15
# 33221 bytes are served to 198.234.90.132 in the hour period 15
# 35156 bytes are served to 199.213.177.192 in the hour period 10
# 2624 bytes are served to 156.80.164.71 in the hour period 17
# 74850 bytes are served to 132.170.199.114 in the hour period 19
# 39573 bytes are served to 156.98.205.38 in the hour period 15
# 57068 bytes are served to 146.184.114.116 in the hour period 12
# 6255 bytes are served to 149.168.105.12 in the hour period 9
# 35198 bytes are served to 131.92.128.99 in the hour period 9
# 83630 bytes are served to 131.178.9.51 in the hour period 13
# 1724 bytes are served to 199.223.31.140 in the hour period 18
# 11746 bytes are served to 198.85.72.63 in the hour period 16
# 31230 bytes are served to 204.62.245.32 in the hour period 18
# 316130 bytes are served to 160.80.14.61 in the hour period 14
# 30674 bytes are served to 167.21.131.14 in the hour period 15
# 16087 bytes are served to 162.80.60.48 in the hour period 18
# 16773 bytes are served to 204.62.245.32 in the hour period 16
# 34504 bytes are served to 203.1.203.120 in the hour period 24
# 20844 bytes are served to 128.97.218.144 in the hour period 20
# 75178 bytes are served to 199.73.129.57 in the hour period 21
# 8280 bytes are served to 146.114.111.32 in the hour period 16
# 62619 bytes are served to 139.230.166.82 in the hour period 24
# 4888 bytes are served to 134.67.75.116 in the hour period 15
# 11747 bytes are served to 199.73.153.153 in the hour period 10
# 108987 bytes are served to 163.234.204.22 in the hour period 16
# 201534 bytes are served to 163.234.112.177 in the hour period 16
# 4888 bytes are served to 205.216.162.12 in the hour period 13
# 16085 bytes are served to 199.89.39.67 in the hour period 18
# 101519 bytes are served to 155.84.91.40 in the hour period 14
# 138410 bytes are served to 155.84.92.3 in the hour period 17
# 232810 bytes are served to 143.166.206.84 in the hour period 10
# 11746 bytes are served to 152.120.119.72 in the hour period 14
# 352420 bytes are served to 130.19.10.65 in the hour period 19
# 24576 bytes are served to 138.145.14.116 in the hour period 16
# 17852 bytes are served to 165.213.131.21 in the hour period 21
# 122103 bytes are served to 164.167.106.160 in the hour period 17
# 15149 bytes are served to 164.167.106.164 in the hour period 15
# 150813 bytes are served to 192.88.13.159 in the hour period 17
# 7513 bytes are served to 129.93.226.66 in the hour period 12
# 3217 bytes are served to 163.234.128.41 in the hour period 10
# 4889 bytes are served to 134.67.162.127 in the hour period 9
# 1246745 bytes are served to 156.98.205.46 in the hour period 12
# 7513 bytes are served to 192.72.60.108 in the hour period 12
# 13336 bytes are served to 155.75.105.213 in the hour period 10
# 12306 bytes are served to 129.237.223.3 in the hour period 18
# 5686 bytes are served to 203.1.203.120 in the hour period 2
# 19645 bytes are served to 200.10.224.30 in the hour period 12
# 8448 bytes are served to 157.190.64.20 in the hour period 7
# 2968838 bytes are served to 198.102.67.27 in the hour period 23
# 0 bytes are served to 155.206.3.82 in the hour period 9
# 294883 bytes are served to 128.120.153.224 in the hour period 19
# 34212 bytes are served to 144.92.184.112 in the hour period 16
# 4889 bytes are served to 147.154.93.125 in the hour period 11
# 14088 bytes are served to 204.188.47.212 in the hour period 2
# 26405 bytes are served to 204.242.57.164 in the hour period 10
# 28053 bytes are served to 192.122.180.23 in the hour period 22
# 11747 bytes are served to 152.123.183.210 in the hour period 9
# 1626 bytes are served to 129.57.33.48 in the hour period 15
# 4888 bytes are served to 147.154.93.125 in the hour period 17
# 4889 bytes are served to 131.44.53.25 in the hour period 11
# 0 bytes are served to 138.87.174.187 in the hour period 22
# 2624 bytes are served to 205.241.144.11 in the hour period 20
# 252733 bytes are served to 150.216.15.85 in the hour period 14
# 454963 bytes are served to 129.130.232.64 in the hour period 18
# 53501 bytes are served to 156.63.99.189 in the hour period 15
# 1158642 bytes are served to 137.219.55.101 in the hour period 24
# 339453 bytes are served to 156.63.59.132 in the hour period 13
# 11746 bytes are served to 194.158.224.98 in the hour period 16
# 18705 bytes are served to 138.87.174.197 in the hour period 19
# 61554 bytes are served to 128.120.68.34 in the hour period 19
# 11746 bytes are served to 156.63.173.125 in the hour period 17
# 45905 bytes are served to 204.233.135.1 in the hour period 18
# 6347 bytes are served to 157.145.93.27 in the hour period 14
# 58220 bytes are served to 164.155.1.107 in the hour period 7
# 291669 bytes are served to 149.252.214.79 in the hour period 11
# 1362 bytes are served to 167.21.131.14 in the hour period 13
# 16454 bytes are served to 132.170.199.124 in the hour period 10
# 11746 bytes are served to 165.235.39.150 in the hour period 17
# 2336 bytes are served to 149.8.43.17 in the hour period 11
# 78256 bytes are served to 198.31.73.63 in the hour period 20
# 11746 bytes are served to 129.93.226.71 in the hour period 14
# 4233 bytes are served to 128.206.30.37 in the hour period 22
# 12130 bytes are served to 128.163.10.219 in the hour period 17
# 33186 bytes are served to 155.84.91.41 in the hour period 11
# 28591 bytes are served to 138.25.148.25 in the hour period 1
# 16040 bytes are served to 162.15.100.123 in the hour period 15
# 8802 bytes are served to 148.129.52.165 in the hour period 13
# 15699 bytes are served to 148.149.108.49 in the hour period 16
# 10297 bytes are served to 140.112.34.207 in the hour period 8
# 4707 bytes are served to 138.87.174.193 in the hour period 17
# 1056768 bytes are served to 141.243.1.172 in the hour period 24
# 7758 bytes are served to 152.165.111.120 in the hour period 6
# 73392 bytes are served to 140.90.166.59 in the hour period 17
# 10925 bytes are served to 142.36.4.198 in the hour period 17
# 5327 bytes are served to 131.144.40.72 in the hour period 13
# 474030 bytes are served to 130.19.10.65 in the hour period 21
# 30237 bytes are served to 204.171.110.3 in the hour period 14
# 11746 bytes are served to 129.238.120.26 in the hour period 15
# 67625 bytes are served to 162.43.21.12 in the hour period 11
# 1523652 bytes are served to 161.122.12.78 in the hour period 5
# 5119 bytes are served to 134.67.162.121 in the hour period 17
# 4889 bytes are served to 193.145.151.115 in the hour period 7
# 55178 bytes are served to 146.64.37.96 in the hour period 11
# 39162 bytes are served to 155.82.20.107 in the hour period 13
# 393035 bytes are served to 160.69.35.16 in the hour period 20
# 3710 bytes are served to 136.210.122.4 in the hour period 6
# 15204 bytes are served to 142.227.56.52 in the hour period 16
# 25393 bytes are served to 159.238.227.132 in the hour period 13
# 133092 bytes are served to 128.253.25.114 in the hour period 17
# 85102 bytes are served to 146.138.145.184 in the hour period 14
# 102607 bytes are served to 192.249.10.16 in the hour period 15
# 9566 bytes are served to 130.95.42.191 in the hour period 5
# 49152 bytes are served to 203.249.9.64 in the hour period 22
# 43100 bytes are served to 164.159.192.31 in the hour period 11
# 8361 bytes are served to 204.238.43.73 in the hour period 16
# 10301 bytes are served to 193.56.6.203 in the hour period 12
# 4889 bytes are served to 193.144.48.169 in the hour period 11
# 4888 bytes are served to 155.84.91.42 in the hour period 16
# 11746 bytes are served to 128.220.72.225 in the hour period 16
# 94474 bytes are served to 199.217.3.169 in the hour period 18
# 15154 bytes are served to 129.190.221.148 in the hour period 14
# 6085 bytes are served to 193.78.67.34 in the hour period 7
# 60876 bytes are served to 141.173.58.82 in the hour period 12
# 7513 bytes are served to 141.243.1.184 in the hour period 7
# 0 bytes are served to 199.16.15.166 in the hour period 15
# 35386 bytes are served to 144.207.78.19 in the hour period 9
# 19488 bytes are served to 132.175.136.162 in the hour period 16
# 11808 bytes are served to 132.170.199.112 in the hour period 19
# 6833 bytes are served to 192.137.113.155 in the hour period 13
# 4889 bytes are served to 146.184.114.114 in the hour period 12
# 122977 bytes are served to 148.149.107.147 in the hour period 13
# 11808 bytes are served to 155.81.101.76 in the hour period 23
# 104910 bytes are served to 204.177.210.133 in the hour period 11
# 10788 bytes are served to 203.2.83.95 in the hour period 20
# 32988 bytes are served to 131.215.67.47 in the hour period 1
# 27049 bytes are served to 156.42.76.162 in the hour period 15
# 11516 bytes are served to 142.106.186.101 in the hour period 10
# 34600 bytes are served to 155.84.91.41 in the hour period 14
# 8091 bytes are served to 141.192.85.41 in the hour period 5
# 374674 bytes are served to 204.7.162.158 in the hour period 13
# 323673 bytes are served to 146.138.145.126 in the hour period 15
# 18181 bytes are served to 128.159.146.92 in the hour period 16
# 344563 bytes are served to 129.237.24.71 in the hour period 15
# 5882 bytes are served to 198.59.241.220 in the hour period 11
# 1140 bytes are served to 129.53.76.146 in the hour period 11
# 61503 bytes are served to 128.158.53.34 in the hour period 17
# 4950 bytes are served to 134.67.162.118 in the hour period 18
# 11747 bytes are served to 167.193.49.75 in the hour period 11
# 133406 bytes are served to 157.190.64.20 in the hour period 8
# 9785 bytes are served to 155.206.3.82 in the hour period 10
# 18900 bytes are served to 168.29.232.156 in the hour period 11
# 252235 bytes are served to 198.137.145.112 in the hour period 16
# 33489 bytes are served to 199.11.48.9 in the hour period 13
# 131631 bytes are served to 204.185.50.21 in the hour period 15
# 19532 bytes are served to 204.62.245.32 in the hour period 1
# 14484 bytes are served to 141.211.86.123 in the hour period 14
# 14392 bytes are served to 198.86.33.115 in the hour period 16
# 29657 bytes are served to 136.205.18.37 in the hour period 15
# 73569 bytes are served to 138.87.164.21 in the hour period 24
# 16636 bytes are served to 152.123.194.6 in the hour period 9
# 81936 bytes are served to 163.234.140.24 in the hour period 10
# 167585 bytes are served to 146.138.145.203 in the hour period 13
# 16682 bytes are served to 202.32.50.6 in the hour period 1
# 142370 bytes are served to 146.114.26.12 in the hour period 21
# 51853 bytes are served to 131.92.168.177 in the hour period 16
# 51661 bytes are served to 192.146.118.133 in the hour period 7
# 59544 bytes are served to 192.234.8.167 in the hour period 18
# 146351 bytes are served to 198.85.72.63 in the hour period 17
# 17550 bytes are served to 158.145.111.130 in the hour period 18
# 116724 bytes are served to 141.173.58.82 in the hour period 13
# 40951 bytes are served to 131.167.99.88 in the hour period 16
# 171542 bytes are served to 194.20.235.12 in the hour period 8
# 62132 bytes are served to 200.246.227.108 in the hour period 13
# 11746 bytes are served to 198.59.96.237 in the hour period 16
# 353226 bytes are served to 147.160.9.21 in the hour period 13
# 11808 bytes are served to 157.92.49.53 in the hour period 17
# 31613 bytes are served to 134.67.247.53 in the hour period 11
# 0 bytes are served to 134.67.39.48 in the hour period 15
# 58182 bytes are served to 146.184.114.114 in the hour period 13
# 31177 bytes are served to 146.184.114.116 in the hour period 13
# 2786 bytes are served to 134.186.194.4 in the hour period 12
# 13603 bytes are served to 130.54.47.156 in the hour period 23
# 30575 bytes are served to 131.167.25.6 in the hour period 12
# 161147 bytes are served to 134.186.196.23 in the hour period 18
# 23944 bytes are served to 165.234.109.10 in the hour period 18
# 224429 bytes are served to 156.41.19.11 in the hour period 17
# 49999 bytes are served to 204.62.245.32 in the hour period 23
# 9807 bytes are served to 163.234.60.163 in the hour period 15
# 21759 bytes are served to 152.120.123.165 in the hour period 16
# 3577 bytes are served to 156.98.205.127 in the hour period 10
# 12444 bytes are served to 204.62.245.32 in the hour period 13
# 38235 bytes are served to 128.97.218.144 in the hour period 17
# 119956 bytes are served to 128.138.177.44 in the hour period 18
# 3050 bytes are served to 161.129.48.162 in the hour period 13
# 11747 bytes are served to 158.111.64.150 in the hour period 11
# 19941 bytes are served to 204.4.34.49 in the hour period 17
# 160320 bytes are served to 164.159.7.12 in the hour period 20
# 92897 bytes are served to 198.77.113.40 in the hour period 18
# 11746 bytes are served to 156.99.78.138 in the hour period 16
# 16530 bytes are served to 129.219.187.109 in the hour period 15
# 3273 bytes are served to 155.84.91.41 in the hour period 16
# 604773 bytes are served to 163.234.224.24 in the hour period 17
# 13404 bytes are served to 155.84.91.40 in the hour period 15
# 13705 bytes are served to 138.87.174.199 in the hour period 18
# 4889 bytes are served to 141.244.142.68 in the hour period 5
# 21694 bytes are served to 155.84.91.42 in the hour period 9
# 3421 bytes are served to 193.63.73.69 in the hour period 11
# 9279 bytes are served to 192.102.13.2 in the hour period 21
# 12588 bytes are served to 163.234.188.21 in the hour period 13
# 60575 bytes are served to 129.252.21.184 in the hour period 17
# 67951 bytes are served to 149.159.22.10 in the hour period 1
# 18323 bytes are served to 192.217.118.24 in the hour period 14
# 10739 bytes are served to 141.243.1.174 in the hour period 1
# 25938 bytes are served to 204.240.48.15 in the hour period 17
# 19645 bytes are served to 147.46.42.11 in the hour period 8
# 18442 bytes are served to 161.122.12.78 in the hour period 2
# 3717 bytes are served to 203.1.203.222 in the hour period 2
# 24398 bytes are served to 128.196.182.10 in the hour period 17
# 62177 bytes are served to 131.92.128.99 in the hour period 8
# 557637 bytes are served to 156.98.205.46 in the hour period 13
# 1098374 bytes are served to 146.138.145.206 in the hour period 16
# 18280 bytes are served to 194.166.2.73 in the hour period 21
# 24710 bytes are served to 204.62.245.32 in the hour period 3
# 3217 bytes are served to 163.234.128.41 in the hour period 19
# 20658 bytes are served to 202.46.240.10 in the hour period 6
# 7030 bytes are served to 204.188.47.212 in the hour period 1
# 9060 bytes are served to 192.58.194.76 in the hour period 17
# 11747 bytes are served to 141.243.1.183 in the hour period 5
# 274182 bytes are served to 192.48.125.149 in the hour period 16
# 156621 bytes are served to 168.95.125.161 in the hour period 3
# 8718 bytes are served to 155.76.34.55 in the hour period 11
# 16900 bytes are served to 138.25.148.25 in the hour period 2
# 9606 bytes are served to 137.44.6.161 in the hour period 5
# 190561 bytes are served to 199.126.17.71 in the hour period 13
# 14506 bytes are served to 138.87.174.181 in the hour period 15
# 299144 bytes are served to 204.242.57.164 in the hour period 11
# 40112 bytes are served to 192.122.180.23 in the hour period 23
# 258067 bytes are served to 128.163.40.45 in the hour period 17
# 26174 bytes are served to 204.176.47.153 in the hour period 24
# 16614 bytes are served to 144.207.78.19 in the hour period 14
# 20811 bytes are served to 141.243.1.172 in the hour period 23
# 11747 bytes are served to 155.78.168.23 in the hour period 11
# 0 bytes are served to 198.234.90.132 in the hour period 16
# 11747 bytes are served to 198.185.178.62 in the hour period 10
# 63753 bytes are served to 156.80.164.71 in the hour period 18
# 11746 bytes are served to 143.202.74.4 in the hour period 15
# 9488 bytes are served to 152.160.78.1 in the hour period 9
# 2258 bytes are served to 205.168.13.11 in the hour period 11
# 103336 bytes are served to 134.186.133.70 in the hour period 17
# 14850 bytes are served to 200.246.240.62 in the hour period 22
# 21817 bytes are served to 165.113.166.116 in the hour period 11
# 0 bytes are served to 134.186.194.4 in the hour period 20
# 4889 bytes are served to 140.115.3.165 in the hour period 4
# 841 bytes are served to 199.199.170.19 in the hour period 10
# 19307 bytes are served to 138.13.122.153 in the hour period 18
# 40575 bytes are served to 130.158.72.126 in the hour period 6
# 11747 bytes are served to 146.167.189.54 in the hour period 10
# 60244 bytes are served to 205.133.189.64 in the hour period 10
# 15341 bytes are served to 204.62.245.32 in the hour period 17
# 24472 bytes are served to 160.80.14.61 in the hour period 13
# 8934 bytes are served to 204.62.245.32 in the hour period 15
# 4996 bytes are served to 129.96.209.96 in the hour period 24
# 15020 bytes are served to 156.63.59.148 in the hour period 11
# 4254 bytes are served to 149.250.222.1 in the hour period 3
# 52522 bytes are served to 141.173.36.74 in the hour period 14
# 208890 bytes are served to 165.151.47.249 in the hour period 13
# 25132 bytes are served to 138.87.174.201 in the hour period 22
# 14507 bytes are served to 198.5.6.113 in the hour period 13
# 2873 bytes are served to 163.234.52.80 in the hour period 9
# 352256 bytes are served to 141.243.1.172 in the hour period 3
# 2235 bytes are served to 137.132.52.66 in the hour period 1
# 63991 bytes are served to 200.246.227.73 in the hour period 19
# 9234 bytes are served to 199.170.121.20 in the hour period 23
# 38129 bytes are served to 155.84.91.42 in the hour period 11
# 23186 bytes are served to 155.75.31.8 in the hour period 12
# 5961 bytes are served to 165.213.131.21 in the hour period 22
# 232428 bytes are served to 198.165.30.147 in the hour period 13
# 0 bytes are served to 38.12.1.53 in the hour period 23
# 11746 bytes are served to 198.85.72.83 in the hour period 15
# 12630 bytes are served to 130.127.84.37 in the hour period 13
# 2624 bytes are served to 165.152.88.75 in the hour period 15
# 30474 bytes are served to 156.98.205.46 in the hour period 11
# 38895 bytes are served to 204.73.0.100 in the hour period 11
# 70986 bytes are served to 193.145.151.115 in the hour period 6
# 14709 bytes are served to 152.35.128.13 in the hour period 16
# 61456 bytes are served to 134.156.8.36 in the hour period 13
# 598 bytes are served to 139.121.50.49 in the hour period 12
# 33310 bytes are served to 139.230.166.82 in the hour period 23
# 217331 bytes are served to 128.252.99.104 in the hour period 15
# 165052 bytes are served to 170.142.111.131 in the hour period 10
# 185550 bytes are served to 128.120.153.224 in the hour period 20
# 235403 bytes are served to 164.64.142.46 in the hour period 15
# 116881 bytes are served to 158.111.96.101 in the hour period 14
# 25621 bytes are served to 203.249.9.64 in the hour period 23
# 15680 bytes are served to 162.43.14.12 in the hour period 18
# 11747 bytes are served to 129.135.216.13 in the hour period 12
# 15917 bytes are served to 163.191.188.77 in the hour period 14
# 19561 bytes are served to 134.20.176.82 in the hour period 17
# 398729 bytes are served to 142.28.2.67 in the hour period 15
# 32988 bytes are served to 204.120.34.204 in the hour period 22
# 4888 bytes are served to 204.32.176.150 in the hour period 17
# 5250 bytes are served to 198.108.132.40 in the hour period 11
# 19910 bytes are served to 138.87.174.187 in the hour period 21
# 237817 bytes are served to 204.178.177.96 in the hour period 18
# 4950 bytes are served to 141.243.1.172 in the hour period 21
# 11746 bytes are served to 198.76.115.66 in the hour period 15
# 18905 bytes are served to 156.80.164.71 in the hour period 16
# 150589 bytes are served to 156.63.99.189 in the hour period 16
# 3838 bytes are served to 137.219.55.101 in the hour period 23
# 7843 bytes are served to 152.160.78.1 in the hour period 11
# 2469 bytes are served to 204.97.2.199 in the hour period 17
# 7513 bytes are served to 134.67.162.127 in the hour period 8
# 6236 bytes are served to 138.13.122.153 in the hour period 14
# 11808 bytes are served to 170.142.111.131 in the hour period 18
# 11515 bytes are served to 163.191.129.33 in the hour period 15
# 16359 bytes are served to 146.137.152.20 in the hour period 12
# 104910 bytes are served to 206.27.204.6 in the hour period 23
# 21522 bytes are served to 157.145.93.27 in the hour period 13
# 209249 bytes are served to 164.155.1.107 in the hour period 8
# 43043 bytes are served to 149.252.214.79 in the hour period 12
# 12649 bytes are served to 129.108.62.218 in the hour period 22
# 11747 bytes are served to 132.170.199.124 in the hour period 9
# 4044 bytes are served to 164.155.1.101 in the hour period 8
# 46335 bytes are served to 156.63.241.112 in the hour period 18
# 104847 bytes are served to 158.229.201.74 in the hour period 17
# 11808 bytes are served to 141.243.1.108 in the hour period 22
# 0 bytes are served to 200.12.140.108 in the hour period 17
# 44592 bytes are served to 147.46.54.149 in the hour period 8
# 11747 bytes are served to 131.182.154.201 in the hour period 12
# 9012 bytes are served to 199.1.106.1 in the hour period 23
# 118463 bytes are served to 204.255.92.30 in the hour period 11
# 12631 bytes are served to 146.138.35.190 in the hour period 11
# 45049 bytes are served to 155.84.91.40 in the hour period 11
# 758336 bytes are served to 204.130.16.23 in the hour period 13
# 444230 bytes are served to 141.161.18.205 in the hour period 10
# 82184 bytes are served to 144.207.78.19 in the hour period 8
# 3842 bytes are served to 130.99.163.23 in the hour period 20
# 11808 bytes are served to 146.138.35.184 in the hour period 18
# 117812 bytes are served to 167.193.53.8 in the hour period 9
# 25431 bytes are served to 198.59.172.45 in the hour period 22
# 11808 bytes are served to 206.27.204.6 in the hour period 21
# 16746 bytes are served to 138.87.174.195 in the hour period 16
# 3508 bytes are served to 199.89.158.67 in the hour period 18
# 0 bytes are served to 128.227.109.32 in the hour period 13
# 131072 bytes are served to 130.19.10.65 in the hour period 22
# 70215 bytes are served to 156.3.41.81 in the hour period 20
# 3866 bytes are served to 204.171.110.3 in the hour period 13
# 21475 bytes are served to 137.227.51.15 in the hour period 13
# 557056 bytes are served to 161.122.12.78 in the hour period 6
# 52293 bytes are served to 137.227.51.13 in the hour period 15
# 5327 bytes are served to 137.187.102.8 in the hour period 13
# 47538 bytes are served to 198.105.194.117 in the hour period 14
# 116404 bytes are served to 198.106.169.52 in the hour period 16
# 35176 bytes are served to 140.183.199.34 in the hour period 11
# 155482 bytes are served to 202.39.249.142 in the hour period 22
# 7574 bytes are served to 155.187.32.163 in the hour period 22
# 7513 bytes are served to 141.243.1.185 in the hour period 5
# 52383 bytes are served to 137.35.140.68 in the hour period 17
# 1045 bytes are served to 203.249.9.64 in the hour period 21
# 4613 bytes are served to 193.144.48.169 in the hour period 12
# 105906 bytes are served to 156.63.91.92 in the hour period 12
# 7030 bytes are served to 198.83.164.2 in the hour period 16
# 4914 bytes are served to 155.95.69.37 in the hour period 18
# 67686 bytes are served to 155.84.91.39 in the hour period 17
# 29597 bytes are served to 192.137.113.155 in the hour period 18
# 17563 bytes are served to 147.97.8.19 in the hour period 17
# 16242 bytes are served to 156.98.205.38 in the hour period 12
# 67686 bytes are served to 139.102.65.59 in the hour period 20
# 11747 bytes are served to 134.186.191.100 in the hour period 12
# 11577 bytes are served to 163.13.143.35 in the hour period 21
# 6391 bytes are served to 159.105.44.21 in the hour period 17
# 26402 bytes are served to 199.8.210.73 in the hour period 22
# 27109 bytes are served to 130.206.105.165 in the hour period 11
# 109309 bytes are served to 206.26.139.13 in the hour period 8
# 16801 bytes are served to 131.167.25.3 in the hour period 9
# 521757 bytes are served to 128.144.102.56 in the hour period 12
# 9569 bytes are served to 163.234.128.29 in the hour period 11
# 11747 bytes are served to 134.164.40.57 in the hour period 10
# 39181 bytes are served to 131.92.128.99 in the hour period 10
# 61669 bytes are served to 128.252.99.104 in the hour period 21
# 35969 bytes are served to 137.113.193.236 in the hour period 17
# 12227 bytes are served to 203.249.9.64 in the hour period 7
# 11808 bytes are served to 128.138.177.19 in the hour period 22
# 35792 bytes are served to 129.228.127.11 in the hour period 14
# 10296 bytes are served to 202.96.29.111 in the hour period 2
# 14370 bytes are served to 144.51.21.1 in the hour period 16
# 47742 bytes are served to 129.190.44.137 in the hour period 9
# 28946 bytes are served to 199.190.82.200 in the hour period 13
# 19828 bytes are served to 156.63.91.107 in the hour period 14
# 11747 bytes are served to 161.119.73.37 in the hour period 20
# 86425 bytes are served to 130.101.13.102 in the hour period 9
# 7512 bytes are served to 163.191.195.25 in the hour period 15
# 74884 bytes are served to 165.1.8.140 in the hour period 13
# 8727 bytes are served to 131.182.170.143 in the hour period 15
# 355697 bytes are served to 148.224.17.200 in the hour period 13
# 2329 bytes are served to 165.113.166.116 in the hour period 17
# 7811 bytes are served to 140.112.68.165 in the hour period 1
# 16131 bytes are served to 137.229.144.53 in the hour period 21
# 0 bytes are served to 130.19.10.65 in the hour period 20
# 14506 bytes are served to 150.148.177.238 in the hour period 16
# 84025 bytes are served to 206.43.171.250 in the hour period 23
# 95214 bytes are served to 204.157.71.59 in the hour period 24
# 70590 bytes are served to 206.43.171.247 in the hour period 23
# 14098 bytes are served to 162.43.21.12 in the hour period 20
# 103014 bytes are served to 192.137.112.52 in the hour period 20
# 4889 bytes are served to 199.190.112.11 in the hour period 11
# 11359 bytes are served to 128.120.125.246 in the hour period 15
# 136611 bytes are served to 128.253.25.114 in the hour period 16
# 1033 bytes are served to 192.48.125.149 in the hour period 10
# 1033087 bytes are served to 146.138.145.184 in the hour period 15
# 72345 bytes are served to 147.160.9.24 in the hour period 10
# 9384 bytes are served to 165.13.6.109 in the hour period 14
# 4889 bytes are served to 170.55.130.21 in the hour period 10
# 39857 bytes are served to 192.239.66.91 in the hour period 13
# 3073 bytes are served to 129.193.171.77 in the hour period 12
# 0 bytes are served to 205.216.194.186 in the hour period 18
# 29844 bytes are served to 204.62.25.132 in the hour period 12
# 84897 bytes are served to 142.25.2.206 in the hour period 20
# 3461 bytes are served to 130.241.163.40 in the hour period 15
# 253685 bytes are served to 199.77.34.51 in the hour period 12
# 3532 bytes are served to 165.151.51.235 in the hour period 13
# 2624 bytes are served to 146.229.1.49 in the hour period 10
# 12630 bytes are served to 129.57.33.48 in the hour period 14
# 19490 bytes are served to 146.129.161.37 in the hour period 17
# 11808 bytes are served to 142.94.10.2 in the hour period 18
# 213214 bytes are served to 198.102.67.27 in the hour period 22
# 206292 bytes are served to 204.91.136.26 in the hour period 17
# 22215 bytes are served to 192.246.82.178 in the hour period 10
# 8618 bytes are served to 137.241.180.13 in the hour period 13
# 1609 bytes are served to 204.62.245.32 in the hour period 5
# 14923 bytes are served to 155.33.62.76 in the hour period 12
# 23494 bytes are served to 141.243.1.182 in the hour period 4
# 4889 bytes are served to 131.203.13.244 in the hour period 2
# 15209 bytes are served to 192.147.170.226 in the hour period 19
# 27323 bytes are served to 139.121.79.159 in the hour period 10
# 130983 bytes are served to 134.20.62.234 in the hour period 14
# 14122 bytes are served to 134.67.57.26 in the hour period 13
# 11746 bytes are served to 128.150.157.33 in the hour period 16
# 61262 bytes are served to 169.14.20.136 in the hour period 14
# 26138 bytes are served to 142.139.220.18 in the hour period 17
# 8050 bytes are served to 131.126.30.164 in the hour period 14
# 38602 bytes are served to 192.195.68.20 in the hour period 16
# 4818505 bytes are served to 139.121.98.45 in the hour period 14
# 67624 bytes are served to 131.250.8.83 in the hour period 13
# 82766 bytes are served to 155.82.161.245 in the hour period 14
# 12419 bytes are served to 134.186.191.52 in the hour period 21
# 0 bytes are served to 128.120.5.70 in the hour period 14
# 17214 bytes are served to 134.67.39.48 in the hour period 11
# 70429 bytes are served to 134.186.194.4 in the hour period 16
# 12400 bytes are served to 134.67.162.127 in the hour period 16
# 17074 bytes are served to 128.159.144.142 in the hour period 9
# 109169 bytes are served to 131.52.16.102 in the hour period 13
# 20660 bytes are served to 131.95.119.99 in the hour period 23
# 49522 bytes are served to 134.67.162.123 in the hour period 14
# 66598 bytes are served to 156.41.19.11 in the hour period 15
# 5119 bytes are served to 134.67.162.121 in the hour period 16
# 27443 bytes are served to 199.11.62.136 in the hour period 12
# 84489 bytes are served to 162.80.100.210 in the hour period 15
# 19645 bytes are served to 204.194.175.23 in the hour period 20
# 8712 bytes are served to 131.90.176.27 in the hour period 16
# 165420 bytes are served to 163.191.186.9 in the hour period 12
# 18257 bytes are served to 158.111.97.43 in the hour period 11
# 3508 bytes are served to 159.230.8.130 in the hour period 17
# 15682 bytes are served to 192.88.13.159 in the hour period 16
# 11747 bytes are served to 141.243.1.186 in the hour period 6
# 93917 bytes are served to 149.25.57.7 in the hour period 17
# 4888 bytes are served to 194.90.3.202 in the hour period 16
# 14416 bytes are served to 134.136.91.60 in the hour period 13
# 531611 bytes are served to 149.168.51.35 in the hour period 16
# 155930 bytes are served to 131.167.48.39 in the hour period 10
# 591857 bytes are served to 129.237.24.71 in the hour period 13
# 5248 bytes are served to 204.249.225.65 in the hour period 15
# 11808 bytes are served to 198.59.96.236 in the hour period 19
# 26806 bytes are served to 139.104.10.120 in the hour period 18
# 6835 bytes are served to 141.243.1.172 in the hour period 1
# 3785626 bytes are served to 203.251.228.110 in the hour period 4
# 88805 bytes are served to 205.218.98.32 in the hour period 23
# 3217 bytes are served to 163.234.128.41 in the hour period 15
# 22726 bytes are served to 155.84.91.41 in the hour period 10
# 15020 bytes are served to 158.72.25.7 in the hour period 12
# 15019 bytes are served to 156.63.59.190 in the hour period 14
# 0 bytes are served to 157.145.93.27 in the hour period 19
# 34037 bytes are served to 160.136.18.53 in the hour period 15
# 19910 bytes are served to 155.75.107.234 in the hour period 10
# 11305 bytes are served to 149.168.25.115 in the hour period 13
# 63856 bytes are served to 128.138.177.6 in the hour period 21
# 30593 bytes are served to 139.121.102.121 in the hour period 23
# 1572 bytes are served to 146.83.128.83 in the hour period 11
# 155335 bytes are served to 38.12.1.131 in the hour period 11
# 6874 bytes are served to 162.108.35.147 in the hour period 14
# 34314 bytes are served to 142.2.32.69 in the hour period 16
# 204373 bytes are served to 204.248.203.107 in the hour period 14
# 60604 bytes are served to 202.32.50.6 in the hour period 3
# 45471 bytes are served to 128.165.180.61 in the hour period 15
# 11746 bytes are served to 128.150.157.33 in the hour period 14
# 63661 bytes are served to 192.146.118.133 in the hour period 5
# 4449 bytes are served to 134.116.4.42 in the hour period 16
# 11747 bytes are served to 192.55.134.51 in the hour period 13
# 2760 bytes are served to 192.55.134.53 in the hour period 13
# 0 bytes are served to 199.222.161.40 in the hour period 13
# 15020 bytes are served to 156.98.204.48 in the hour period 12
# 152564 bytes are served to 131.178.81.68 in the hour period 17
# 20464 bytes are served to 198.215.148.51 in the hour period 15
# 31060 bytes are served to 157.142.200.132 in the hour period 17
# 126340 bytes are served to 131.52.16.102 in the hour period 11
# 147822 bytes are served to 150.200.42.20 in the hour period 11
# 11746 bytes are served to 199.111.26.62 in the hour period 13
# 7513 bytes are served to 157.22.192.30 in the hour period 1
# 28746 bytes are served to 156.63.59.149 in the hour period 18
# 8486 bytes are served to 204.27.135.130 in the hour period 10
# 22149 bytes are served to 134.243.205.146 in the hour period 10
# 4888 bytes are served to 131.52.16.102 in the hour period 15
# 102679 bytes are served to 198.104.228.83 in the hour period 16
# 140056 bytes are served to 198.109.136.238 in the hour period 14
# 38313 bytes are served to 153.90.241.102 in the hour period 16
# 2624 bytes are served to 128.192.24.215 in the hour period 17
# 13870 bytes are served to 141.192.85.41 in the hour period 3
# 12450 bytes are served to 134.243.205.184 in the hour period 10
# 70820 bytes are served to 156.63.91.107 in the hour period 16
# 3214762 bytes are served to 155.84.92.3 in the hour period 16
# 81490 bytes are served to 128.227.152.54 in the hour period 9
# 14450 bytes are served to 156.80.94.51 in the hour period 11
# 11747 bytes are served to 204.97.68.29 in the hour period 9
# 64249 bytes are served to 149.168.50.194 in the hour period 16
# 106596 bytes are served to 204.250.9.58 in the hour period 19
